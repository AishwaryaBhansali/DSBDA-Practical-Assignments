# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in d:\study material\dsbd\venv\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in d:\study material\dsbd\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\study material\dsbd\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in d:\study material\dsbd\venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in d:\study material\dsbd\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\study material\dsbd\venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\study material\dsbd\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked AgeGroup
# 0        0         A/5 21171   7.2500   NaN        S    Adult
# 1        0          PC 17599  71.2833   C85        C    Adult
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Adult
# 3        0            113803  53.1000  C123        S    Adult
# 4        0            373450   8.0500   NaN        S    Adult
# ..     ...               ...      ...   ...      ...      ...
# 886      0            211536  13.0000   NaN        S    Adult
# 887      0            112053  30.0000   B42        S    Youth
# 888      2        W./C. 6607  23.4500   NaN        S    Youth
# 889      0            111369  30.0000  C148        C    Adult
# 890      0            370376   7.7500   NaN        Q    Adult
#
# [891 rows x 13 columns]

# %%
plt.figure(figsize=(6,4))
plt.title("Distribution of age with respect to gender")
plt.xlabel('Gender')
plt.ylabel('Age')
sns.boxplot(data=df, x='Sex', y='Age')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.title("Distribution of age with respect to gender")
plt.xlabel('Gender')
plt.ylabel('Age')
sns.boxplot(data=df, x='Sex', y='Age', hue='Survived')
plt.show()
